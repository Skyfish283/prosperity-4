# %%
import pandas as pd

# %%
alldata = pd.read_csv('sample_data.csv',sep=';')

# %%
am = alldata[alldata['product']=='AMETHYSTS']

# %%
import matplotlib.pyplot as plt;

am = am[am['timestamp'] % 1000 == 0]

plt.plot(am['timestamp'],am['bid_price_1'])
ax = plt.gca()
ax.set_xlim([0, 200000])
ax.set_ylim([9990, 10010])
plt.show()
